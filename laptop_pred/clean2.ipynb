# %%
import pandas as pd
df = pd.read_csv('cleaned_laptopData2.csv')
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1265  Lenovo  2 in 1 Convertible    14.0
# 1266  Lenovo  2 in 1 Convertible    13.3
# 1267  Lenovo            Notebook    14.0
# 1268      HP            Notebook    15.6
# 1269    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1265   IPS Panel Full HD / Touchscreen 1920x1080
# 1266  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.loc[df['Memory'] < 32, 'Memory'] = df['Memory'].mode()

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1265  Lenovo  2 in 1 Convertible    14.0
# 1266  Lenovo  2 in 1 Convertible    13.3
# 1267  Lenovo            Notebook    14.0
# 1268      HP            Notebook    15.6
# 1269    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1265   IPS Panel Full HD / Touchscreen 1920x1080
# 1266  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
int(df['Weight'].min())
# Out:
# 0

# %%
rounded = round(df['Weight'].mean(), 2)
df.loc[df['Weight'] < 0.8, 'Weight'] = rounded

# %%
rounded = round(df['Weight'].mean(), 2)
df.loc[df['Weight'] > 5, 'Weight'] = rounded

# %%
df['Weight'].max()
# Out:
# np.float64(4.7)

# %%
df.to_csv("cleaned_laptopData2.csv", index=False)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1265  Lenovo  2 in 1 Convertible    14.0
# 1266  Lenovo  2 in 1 Convertible    13.3
# 1267  Lenovo            Notebook    14.0
# 1268      HP            Notebook    15.6
# 1269    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1265   IPS Panel Full HD / Touchscreen 1920x1080
# 1266  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Price'].max()
# Out:
# np.float64(324954.72)

# %%
df.loc[df['Price'] < 10000, 'Price'] = df['Price'].mean()

# %%
df.to_csv("cleaned_laptopData.csv", index=False)

# %%
df.isnull().sum()
# Out:
# Company               0
# TypeName              0
# Inches                0
# ScreenResolution      0
# Cpu                   0
# Ram                   0
# Memory              270
# Gpu                   0
# OpSys                 0
# Weight                0
# Price                 0
# dtype: int64

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1265  Lenovo  2 in 1 Convertible    14.0
# 1266  Lenovo  2 in 1 Convertible    13.3
# 1267  Lenovo            Notebook    14.0
# 1268      HP            Notebook    15.6
# 1269    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1265   IPS Panel Full HD / Touchscreen 1920x1080
# 1266  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Memory'] = df['Memory'].fillna(df['Memory'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.to_csv("cleaned_laptopData.csv", index=False)

# %%
df['Company'].nunique()
# Out:
# 19

# %%
df.shape
# Out:
# (1270, 11)

# %%
import joblib

# Load model
model = joblib.load('laptop_price_predictor.pkl')

# %%
sample_data = [["Apple","Ultrabook",15.4,"IPS Panel Retina Display", "2880x1800","Intel Core i7" ,2.7,16,512.0,"AMD Radeon Pro 455","macOS",1.83]]
prediction = model.predict(sample_data)
print("Prediction:", prediction)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 sample_data = [["Apple","Ultrabook",15.4,"IPS Panel Retina Display", "2880x1800","Intel Core i7" ,2.7,16,512.0,"AMD Radeon Pro 455","macOS",1.83]]
# ----> 2 prediction = model.predict(sample_data)
#       3 print("Prediction:", prediction)
#
# AttributeError: 'dict' object has no attribute 'predict'
